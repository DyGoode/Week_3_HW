# %% [markdown]
# ##  Exercise 1:
# Discuss what other classes, methods, or fields (attributes) we could make to improve our streaming service using these principles. <br> <br>
# Start making a few of them and see where it leads...

# %%
# We could search by...
   
    
# ACTOR-ACTRESS:
#     we could maybe call a class Character(self)
#     def __init__(self):
#             blah
#             blah
#             blah
    
#     then
#     def people_search():
#         make a query for cast
#         check the status code 
    
    
#     i think we could do a seperate method 
#     def get_people_shows():
#         shows_person_in []
#         take input = ("Who are you looking for? ")
#         person = input
#         for cast in shows:
#             if person in cast:
#                 shows_person_in.append(show)
#                 return 
        
        
#     another method that would allow them to browse then select from that list
#     def show_list():
#         input = (f"Which show from the list above that include {self.name} would you like to watch")
#         show_wanna_watch = input
#         we could call then call the play method from the series class to then play the selected show
        
    
#RATINGS:
# we could call a class of 
#     class Rating_search(self):
#         def __init__(self):
#             blah
#             blah 
#             blah
            
#     def rating_search():
#         make a query for ratings 
#         check the status code 
        
#     def show_rating():
#         rating_choices = []
#         that will find all applicable rating choices 
#         then put them into an empty list
        
#         shows_with_average_rating = []
#         shows_with_blah_rating = []
#         shows_with_blah2_rating = []
#         shows_with_blah3_rating = []
#         shows_with_blah4_rating = []
#         something that will pull all shows with that specific rating
#         somethign with a bunch of if/elif/else statements 
#         like ....
#         if rating_wanted == "average":
#             shows_with_average_rating.append(show)
#         elif rating_wanted == "blah":
#             shows_with_blah_rating.append(show)
#         elif rating_wanted == "blah2":
#             shows_with_blah2_rating.append(show)
#         elif rating_wanted == "blah3":
#             shows_with_blah3_rating.append(show)
#         elif rating_wanted == "blah4":
#             shows_with_blah4_rating.append(show)
#         else:
#             print(f"Invalid selection: please check spelling and choose a rating from the list.")
        
#         return rating_choices
    
#     def choose_rating():
#         one shown rating choices 
#         input = ("Which rating would you like to explore? ")
#         rating_wanted = input
        
#     def explore_rating():
#         once specific rating is selected 
#         they are  shown all of the shows with that rating 
#         user gives 
#         user selects show
#         input = ("Which show did you choose?")
#         show_choice = input
        
#         call play method from class Series
